# %% [markdown]
# # Задача 1

# %%
class Node:
    def __init__(self, data):
        self.item = data
        self.nref = None


class LinkedList:
    def __init__(self):
        self.start_node = None

    def insert_in_emptylist(self, data):
        if self.start_node is None:
            new_node = Node(data)
            self.start_node = new_node
        else:
            print("list is not empty")

    def insert_at_start(self, data):
        if self.start_node is None:
            new_node = Node(data)
            self.start_node = new_node
            print("node inserted")
            return
        new_node = Node(data)
        new_node.nref = self.start_node
        self.start_node = new_node

    def insert_at_end(self, data):
        if self.start_node is None:
            new_node = Node(data)
            self.start_node = new_node
            return
        n = self.start_node
        while n.nref is not None:
            n = n.nref
        new_node = Node(data)
        n.nref = new_node

    def insert_after_item(self, x, data):
        if self.start_node is None:
            print("List is empty")
            return
        else:
            n = self.start_node
            while n is not None:
                if n.item == x:
                    break
                n = n.nref
            if n is None:
                print("item not in the list")
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                n.nref = new_node

    def insert_before_item(self, x, data):
        if self.start_node is None:
            print("List is empty")
            return
        else:
            n = self.start_node
            while n is not None:
                if n.item == x:
                    break
                n = n.nref
            if n is None:
                print("item not in the list")
            else:
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None:
                    n.pref.nref = new_node
                n.pref = new_node

    def traverse_list(self):
        if self.start_node is None:
            print("List has no element")
            return
        else:
            n = self.start_node
            while n is not None:
                print(n.item, " ")
                n = n.nref

    def delete_at_start(self):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        self.start_node = self.start_node.nref

    def delete_at_end(self):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        if self.start_node.nref is None:
            self.start_node = None
            return
        n = self.start_node
        while n.nref.nref is not None:
            n = n.nref
        n.nref = None

    def delete_element_by_value(self, x):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        if self.start_node.item == x:
            self.start_node = self.start_node.nref
            return
        n = self.start_node
        while n.nref is not None:
            if n.nref.item == x:
                break
            n = n.nref
        if n.nref is None:
            print("Element not found")
        else:
            n.nref = n.nref.nref

    def reverse_linked_list(self):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        prev = None
        n = self.start_node
        while n is not None:
            next_node = n.nref
            n.nref = prev
            prev = n
            n = next_node
        self.start_node = prev

    def find_element(self, x):
        n = self.start_node
        while n is not None:
            if n.item == x:
                return True
            n = n.nref
        return False

    def get_last_element(self):
        if self.start_node is None:
            return None
        n = self.start_node
        while n.nref is not None:
            n = n.nref
        return n.item

    def difference_with_end(self):
        if self.start_node is None:
            return []
        values = []
        n = self.start_node
        while n is not None:
            values.append(n.item)
            n = n.nref
        last_value = self.get_last_element()
        result = []
        for value in values:
            result.append(value - last_value)
        return result

# %% [markdown]
# # Задача 2

# %%
class Node:
    def __init__(self, data):
        self.item = data
        self.nref = None
        self.pref = None


class DoublyLinkedList:
    def __init__(self):
        self.start_node = None

    def insert_in_emptylist(self, data):
        if self.start_node is None:
            new_node = Node(data)
            self.start_node = new_node
        else:
            print("list is not empty")

    def insert_at_start(self, data):
        if self.start_node is None:
            new_node = Node(data)
            self.start_node = new_node
            print("node inserted")
            return
        new_node = Node(data)
        new_node.nref = self.start_node
        self.start_node.pref = new_node
        self.start_node = new_node

    def insert_at_end(self, data):
        if self.start_node is None:
            new_node = Node(data)
            self.start_node = new_node
            return
        n = self.start_node
        while n.nref is not None:
            n = n.nref
        new_node = Node(data)
        n.nref = new_node
        new_node.pref = n

    def insert_after_item(self, x, data):
        if self.start_node is None:
            print("List is empty")
            return
        else:
            n = self.start_node
            while n is not None:
                if n.item == x:
                    break
                n = n.nref
            if n is None:
                print("item not in the list")
            else:
                new_node = Node(data)
                new_node.pref = n
                new_node.nref = n.nref
                if n.nref is not None:
                    n.nref.prev = new_node
                n.nref = new_node

    def insert_before_item(self, x, data):
        if self.start_node is None:
            print("List is empty")
            return
        else:
            n = self.start_node
            while n is not None:
                if n.item == x:
                    break
                n = n.nref
            if n is None:
                print("item not in the list")
            else:
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None:
                    n.pref.nref = new_node
                n.pref = new_node

    def traverse_list(self):
        if self.start_node is None:
            print("List has no element")
            return
        else:
            n = self.start_node
            while n is not None:
                print(n.item, " ")
                n = n.nref

    def delete_at_start(self):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        if self.start_node.nref is None:
            self.start_node = None
            return
        self.start_node = self.start_node.nref
        self.start_node.pref = None

    def delete_at_end(self):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        if self.start_node.nref is None:
            self.start_node = None
            return
        n = self.start_node
        while n.nref is not None:
            n = n.nref
        n.pref.nref = None

    def delete_element_by_value(self, x):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        if self.start_node.nref is None:
            if self.start_node.item == x:
                self.start_node = None
            else:
                print("Item not found")
                return

        if self.start_node.item == x:
            self.start_node = self.start_node.nref
            self.start_node.pref = None
            return

        n = self.start_node
        while n.nref is not None:
            if n.item == x:
                break
            n = n.nref
        if n.nref is not None:
            n.pref.nref = n.nref
            n.nref.pref = n.pref
        else:
            if n.item == x:
                n.pref.nref = None
            else:
                print("Element not found")

    def reverse_linked_list(self):
        if self.start_node is None:
            print("The list has no element to delete")
            return
        p = self.start_node
        q = p.nref
        p.nref = None
        p.pref = q
        while q is not None:
            q.pref = q.nref
            q.nref = p
            p = q
            q = q.pref
        self.start_node = p

    def traverse_reverse(self):
        if self.start_node is None:
            print("List has no element")
            return
        n = self.start_node
        while n.nref is not None:
            n = n.nref
        while n is not None:
            print(n.item, " ")
            n = n.pref

    def symmetric_difference(self):
        if self.start_node is None:
            return []

        right = self.start_node
        while right.nref is not None:
            right = right.nref

        left = self.start_node
        result = []

        while left != right and left.nref != right:
            result.append(left.item - right.item)
            left = left.nref
            right = right.pref

        if left != right and left.nref == right:
            result.append(left.item - right.item)

        return result


list1 = DoublyLinkedList()

list1.insert_at_end(10)
list1.insert_at_end(20)
list1.insert_at_end(30)
list1.insert_at_start(5)

list1.traverse_reverse()
# Out:
# 30
# 20
# 10
# 5

# %% [markdown]
# # Задача 3

# %%
list1 = LinkedList()

list1.insert_at_end(10)
list1.insert_at_end(20)
list1.insert_at_end(30)
list1.insert_at_start(5)

seq = list1.difference_with_end()
print(*seq)
# Out:
# -25 -20 -10 0

# %% [markdown]
# # Задача 4

# %%
list1 = DoublyLinkedList()

list1.insert_at_end(10)
list1.insert_at_end(20)
list1.insert_at_end(30)
list1.insert_at_start(5)

delete_item = int(input())

list1.delete_element_by_value(delete_item)
list1.traverse_list()
# Out:
#  20
# 5
# 10
# 30

# %% [markdown]
# # Задача 5

# %%
list1 = DoublyLinkedList()

list1.insert_at_end(10)
list1.insert_at_end(20)
list1.insert_at_end(30)
list1.insert_at_start(5)

seq = list1.symmetric_difference()
print(*seq)
# Out:
# -25 -10

# %% [markdown]
# # Задача 6

# %%
class Node:
    def __init__(self, data):
        self.item = data
        self.nref = None
        self.pref = None


class Stack:
    def __init__(self):
        self.stack_pointer = None

    def push(self, data):
        new_node = Node(data)
        if self.stack_pointer is None:
            self.stack_pointer = new_node
        else:
            new_node.nref = self.stack_pointer
            self.stack_pointer.pref = new_node
            self.stack_pointer = new_node

    def pop(self):
        if self.stack_pointer is None:
            print("Stack is empty")
            return None
        top_item = self.stack_pointer.item
        if self.stack_pointer.nref is None:
            self.stack_pointer = None
        else:
            self.stack_pointer = self.stack_pointer.nref
            self.stack_pointer.pref = None
        return top_item

    def top(self):
        if self.stack_pointer is None:
            print("Stack is empty")
            return None
        return self.stack_pointer.item

    def size(self):
        count = 0
        n = self.stack_pointer
        while n is not None:
            count += 1
            n = n.nref
        return count

    def isempty(self):
        return self.stack_pointer is None

    def printstack(self):
        if self.stack_pointer is None:
            print("Stack is empty")
            return
        n = self.stack_pointer
        while n is not None:
            print(n.item, " ")
            n = n.nref


stack = Stack()

stack.push(10)
stack.push(20)
stack.push(30)

print(stack.top())

stack.pop()

print(stack.top())

print(stack.size())

stack.printstack()
# Out:
# 30
# 20
# 2
# 20
# 10

# %% [markdown]
# # Задача 1

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def issymmetric(tree):
    if tree is None:
        return True
    return ismirror(tree.left, tree.right)


def ismirror(left, right):
    if left is None and right is None:
        return True
    if left is None or right is None:
        return False
    if left.val != right.val:
        return False
    return ismirror(left.left, right.right) and ismirror(left.right, right.left)


tree = TreeNode(1)
tree.left = TreeNode(2)
tree.right = TreeNode(2)
tree.left.left = TreeNode(3)
tree.left.right = TreeNode(4)
tree.right.left = TreeNode(4)
tree.right.right = TreeNode(3)

print(issymmetric(tree))
# Out:
# True

# %% [markdown]
# # Задача 4

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def mirror_tree(tree):
    if tree is None:
        return

    tree.left, tree.right = tree.right, tree.left

    mirror_tree(tree.left)
    mirror_tree(tree.right)


def print_tree(tree):
    def traverse(node):
        if node is None:
            return

        if node.left is not None:
            print(" PARENT : " + str(node.val) + " LEFT CHILD : " +
                  str(node.left.val) + " RIGHT CHILD : " +
                  str(node.right.val))

        traverse(node.left)
        traverse(node.right)

    traverse(tree)


tree = TreeNode(1)
tree.left = TreeNode(6)
tree.right = TreeNode(2)
tree.left.left = TreeNode(5)
tree.left.right = TreeNode(7)
tree.right.left = TreeNode(4)
tree.right.right = TreeNode(3)

print("До:")
print_tree(tree)

mirror_tree(tree)

print("После:")
print_tree(tree)
# Out:
# До:
#  PARENT : 1 LEFT CHILD : 6 RIGHT CHILD : 2
#  PARENT : 6 LEFT CHILD : 5 RIGHT CHILD : 7
#  PARENT : 2 LEFT CHILD : 4 RIGHT CHILD : 3
# После:
#  PARENT : 1 LEFT CHILD : 2 RIGHT CHILD : 6
#  PARENT : 2 LEFT CHILD : 3 RIGHT CHILD : 4
#  PARENT : 6 LEFT CHILD : 7 RIGHT CHILD : 5

# %% [markdown]
# # Задача 5

# %%
class Node:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def find_parents(tree, target):
    if tree is None:
        return None

    if tree.val == target:
        return []

    left_result = find_parents(tree.left, target)

    right_result = find_parents(tree.right, target)

    if left_result is not None:
        return [tree.val] + left_result

    if right_result is not None:
        return [tree.val] + right_result

    return None


tree = Node(1)
tree.left = Node(2)
tree.right = Node(3)
tree.left.left = Node(4)
tree.left.left.left = Node(6)

parents = find_parents(tree, 6)
print(*parents)
# Out:
# 1 2 4
